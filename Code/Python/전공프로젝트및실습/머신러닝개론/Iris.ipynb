# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

data = np.loadtxt('C:/Users/사용자/Desktop/Iris.csv', unpack=True, delimiter = ',', skiprows=0)
#0. sepal length / 1. sepal width / 3. petal length / 4. petal width / 6. sepal Area / 7. petal Area
plt.plot(data[0], data[1], 'o', markersize=3)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.grid()
plt.suptitle('2d plotting_1', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_1.png')
plt.show()

plt.plot(data[0], data[2], 'o', markersize=3)
plt.xlabel('sepal length')
plt.ylabel('petal length')
plt.grid()
plt.suptitle('2d plotting_2', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_2.png')
plt.show()

plt.plot(data[0], data[3], 'o', markersize=3)
plt.xlabel('sepal length')
plt.ylabel('petal width')
plt.grid()
plt.suptitle('2d plotting_3', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_3.png')
plt.show()

plt.plot(data[1], data[2], 'o', markersize=3)
plt.xlabel('sepal width')
plt.ylabel('petal length')
plt.grid()
plt.suptitle('2d plotting_4', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_4.png')
plt.show()

plt.plot(data[1], data[3], 'o', markersize=3)
plt.xlabel('sepal width')
plt.ylabel('petal width')
plt.grid()
plt.suptitle('2d plotting_5', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_5.png')
plt.show()

plt.plot(data[2], data[3], 'o', markersize=3)
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.grid()
plt.suptitle('2d plotting_6', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_6.png')
plt.show()

plt.plot(data[0], data[1], 'o', markersize=3)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.grid()
plt.suptitle('2d plotting_hw1_2', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_HW1_2.png')
plt.show()

fig = plt.figure()
ax = Axes3D(fig)
X=data[0]
Y=data[1]
Z=data[4]

ax.scatter(X,Y,Z)
ax.set_xlabel('sepal length')
ax.set_ylabel('sepal width')
ax.set_zlabel('class')
plt.suptitle('3d plotting_hw1_3', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_HW1_3.png')
plt.show()

fig = plt.figure()
ax = Axes3D(fig)
X=data[0]
Y=data[3]
Z=data[4]

ax.scatter(X,Y,Z)
ax.set_xlabel('sepal length')
ax.set_ylabel('petal length')
ax.set_zlabel('class')
plt.suptitle('3d plotting_hw1_3_2', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_HW1_3_2.png')
plt.show()

fig = plt.figure()
ax = Axes3D(fig)
X=data[1]
Y=data[3]
Z=data[4]

ax.scatter(X,Y,Z)
ax.set_xlabel('sepal width')
ax.set_ylabel('petal length')
ax.set_zlabel('class')
plt.suptitle('3d plotting_hw1_3_2', fontsize=16)
plt.savefig('C:/Users/사용자/Desktop/Iris_HW1_3_3.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1b08bdd88ef7> in <module>
# ----> 1 import tensorflow as tf
#       2 import matplotlib.pyplot as plt
#       3 from mpl_toolkits.mplot3d import Axes3D
#       4 import numpy as np
#       5
#
# C:\user\lib\site-packages\tensorflow\__init__.py in <module>
#      39 from tensorflow._api.v1 import autograph
#      40 from tensorflow._api.v1 import bitwise
# ---> 41 from tensorflow._api.v1 import compat
#      42 from tensorflow._api.v1 import config
#      43 from tensorflow._api.v1 import data
#
# C:\user\lib\site-packages\tensorflow\_api\v1\compat\__init__.py in <module>
#      19 from __future__ import print_function as _print_function
#      20
# ---> 21 from tensorflow._api.v1.compat import v1
#      22 from tensorflow._api.v1.compat import v2
#      23 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# C:\user\lib\site-packages\tensorflow\_api\v1\compat\v1\__init__.py in <module>
#     647 _current_module = _sys.modules[__name__]
#     648 try:
# --> 649   from tensorflow_estimator.python.estimator.api._v1 import estimator
#     650   _current_module.__path__ = (
#     651       [_module_util.get_parent_dir(estimator)] + _current_module.__path__)
#
# C:\user\lib\site-packages\tensorflow_estimator\python\estimator\__init__.py in <module>
#      23 from __future__ import print_function
#      24
# ---> 25 import tensorflow_estimator.python.estimator.estimator_lib
#      26
#
# C:\user\lib\site-packages\tensorflow_estimator\python\estimator\estimator_lib.py in <module>
#      51 from tensorflow_estimator.python.estimator.hooks import hooks
#      52 from tensorflow_estimator.python.estimator.hooks import session_run_hook
# ---> 53 from tensorflow_estimator.python.estimator.inputs import inputs
#      54 from tensorflow_estimator.python.estimator.keras import model_to_estimator
#      55 from tensorflow_estimator.python.estimator.mode_keys import ModeKeys
#
# C:\user\lib\site-packages\tensorflow_estimator\python\estimator\inputs\inputs.py in <module>
#      20
#      21 # pylint: disable=unused-import,line-too-long
# ---> 22 from tensorflow_estimator.python.estimator.inputs.numpy_io import numpy_input_fn
#      23 from tensorflow_estimator.python.estimator.inputs.pandas_io import pandas_input_fn
#      24
#
# C:\user\lib\site-packages\tensorflow_estimator\python\estimator\inputs\numpy_io.py in <module>
#      24 from six import string_types
#      25
# ---> 26 from tensorflow_estimator.python.estimator.inputs.queues import feeding_functions
#      27 from tensorflow.python.util.tf_export import estimator_export
#      28
#
# C:\user\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py in <module>
#      38 try:
#      39   # pylint: disable=g-import-not-at-top
# ---> 40   import pandas as pd
#      41   HAS_PANDAS = True
#      42 except IOError:
#
# C:\user\lib\site-packages\pandas\__init__.py in <module>
#      28
#      29 try:
# ---> 30     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#      31 except ImportError as e:  # pragma: no cover
#      32     # hack but overkill to use re
#
# C:\user\lib\site-packages\pandas\_libs\__init__.py in <module>
#       1 # flake8: noqa
#       2
# ----> 3 from .tslibs import (
#       4     NaT,
#       5     NaTType,
#
# C:\user\lib\site-packages\pandas\_libs\tslibs\__init__.py in <module>
#       1 # flake8: noqa
#       2
# ----> 3 from .conversion import localize_pydatetime, normalize_date
#       4 from .nattype import NaT, NaTType, iNaT, is_null_datetimelike
#       5 from .np_datetime import OutOfBoundsDatetime
#
# pandas\_libs\tslibs\conversion.pyx in init pandas._libs.tslibs.conversion()
#
# AttributeError: type object 'pandas._libs.tslibs.conversion._TSObject' has no attribute '__reduce_cython__'
